# %% [markdown]
# Euler #8:
#
# The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.
#
# 73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450
#
# Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

# %%
nums = """
73167176531330624919225119674426574742355349194934
96983520312774506326239578318016984801869478851843
85861560789112949495459501737958331952853208805511
12540698747158523863050715693290963295227443043557
66896648950445244523161731856403098711121722383113
62229893423380308135336276614282806444486645238749
30358907296290491560440772390713810515859307960866
70172427121883998797908792274921901699720888093776
65727333001053367881220235421809751254540594752243
52584907711670556013604839586446706324415722155397
53697817977846174064955149290862569321978468622482
83972241375657056057490261407972968652414535100474
82166370484403199890008895243450658541227588666881
16427171479924442928230863465674813919123162824586
17866458359124566529476545682848912883142607690042
24219022671055626321111109370544217506941658960408
07198403850962455444362981230987879927244284909188
84580156166097919133875499200524063689912560717606
05886116467109405077541002256983155200055935729725
71636269561882670428252483600823257530420752963450
"""

nums = nums.replace('\n', '')
nums
# Out:
# '...'

# %%
len(nums)
# Out:
# 1000

# %%
from timeit import default_timer as timer

def get_largest_product(numstring, digits):
    
    total = 1 
    counter = 0        

    for i in range(len(numstring)+1):
        substring = numstring[i:i+digits]
        if '0' in substring:
            pass
        else:
            temp_total = 1
            for num in substring:
                temp_total *= int(num)
            if temp_total > total:
                total = temp_total
        counter += 1
    
    return counter, total

start = timer()
counter, largest_product = get_largest_product(nums, 13)
stop = timer()

print('Answer:', largest_product)
print('Process Time:', stop-start, 'seconds')
print('Number of Iterations:', counter)
# Out:
# Answer: 23514624000
# Process Time: 0.0010391999999797008 seconds
# Number of Iterations: 1001

# %%
from timeit import default_timer as timer
import numpy as np

def get_largest_product_efficient(numstring, digits):
    
    total = 1
    counter = 0
    i = 0
    
    while i <= len(numstring)-digits:  # while loop because number of iterations is unknown.
        substring = numstring[i:i+digits]
        if '0' in substring:  # if 0 is encountered, the next n iterations will all be 0. Skip.
            i += digits 
        else:
            temp_total = 1
            for num in substring:
                temp_total *= int(num)
            if temp_total > total:
                total = temp_total
            i += 1    
        counter += 1
        
        print(substring)
    
    return counter, total
       
    
start = timer()
counter, largest_product = get_largest_product_efficient(nums, 13)
stop = timer()

print('Answer:', largest_product)
print('Process Time:', stop-start, 'seconds')
print('Number of Iterations:', counter)
# Out:
# 7316717653133
# 3167176531330
# 6249192251196
# 2491922511967
# 4919225119674
# 9192251196744
# 1922511967442
# 9225119674426
# 2251196744265
# 2511967442657
# 5119674426574
# 1196744265747
# 1967442657474
# 9674426574742
# 6744265747423
# 7442657474235
# 4426574742355
# 4265747423553
# 2657474235534
# 6574742355349
# 5747423553491
# 7474235534919
# 4742355349194
# 7423553491949
# 4235534919493
# 2355349194934
# 3553491949349
# 5534919493496
# 5349194934969
# 3491949349698
# 4919493496983
# 9194934969835
# 1949349698352
# 9493496983520
# 3127745063262
# 3957831801698
# 4801869478851
# 8438586156078
# 9112949495459
# 1129494954595
# 1294949545950
# 1737958331952
# 7379583319528
# 3795833195285
# 7958331952853
# 9583319528532
# 5833195285320
# 8805511125406
# 9874715852386
# 8747158523863
# 7471585238630
# 5071569329096
# 3295227443043
# 5576689664895
# 5766896648950
# 4452445231617
# 4524452316173
# 5244523161731
# 2445231617318
# 4452316173185
# 4523161731856
# 5231617318564
# ...

# %%
from timeit import default_timer as timer
from functools import reduce
import operator

def cut_adj_chunks(iterable, chunk_size):
    for i in range(len(iterable) - chunk_size):
        yield iterable[i:i+chunk_size]

def sum_prod(num_str):
    num_list = map(int, num_str)
    return reduce(operator.mul, num_list, 1)

def largest_prod(adj_digits, big_num):
    return max(sum_prod(chunk) for chunk in cut_adj_chunks(str(big_num), adj_digits))

start = timer()
largest_prod(13, nums)
stop = timer()

print('Answer:', largest_product)
print('Process Time:', stop-start, 'seconds')
# Out:
# Answer: 23514624000
# Process Time: 0.004339399999935267 seconds

# %%
substring = '123456789'
total = 1
total *= np.prod([int(num) for num in substring])

total
# Out:
# 362880
